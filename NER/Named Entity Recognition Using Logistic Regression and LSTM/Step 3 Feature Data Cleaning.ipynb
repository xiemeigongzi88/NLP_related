# %% [markdown]
# # Step 3 Feature Data Cleaning

# %%
import pandas as pd 

import os 
os.getcwd()

path ="C:\\Users\\sxw17\\Desktop\\2019 Fall\\NLP\\assignment\\Project_2\\submitted version"
os.chdir(path)

# %%
import pandas as pd 

df_train=pd.read_csv("train_extracted_features_step_2.csv", index_col=0)

df_test = pd.read_csv("test_extracted_features_step_2.csv", index_col=0)

# %%
df_train
# Out:
#            sentence          word pos_tag chunk_tag ner_tag        lemmas  \
# document
# doc_0         sen_0            eu     NNP      B-NP   B-ORG            eu
# doc_0         sen_0       rejects     VBZ      B-VP       O        reject
# doc_0         sen_0        german      JJ      B-NP  B-MISC        german
# doc_0         sen_0          call      NN      I-NP       O          call
# doc_0         sen_0            to      TO      B-VP       O            to
# ...             ...           ...     ...       ...     ...           ...
# doc_1161  sen_18450             .       .         O       O             .
# doc_1161  sen_18451            --       :         O       O            --
# doc_1161  sen_18451         dhaka     NNP      B-NP   B-ORG         dhaka
# doc_1161  sen_18451      newsroom     NNP      I-NP   I-ORG      newsroom
# doc_1161  sen_18451  880-2-506363      CD      I-NP     NaN  880-2-506363
#
#                                                   hypernyms  \
# ...

# %%
df_test
# Out:
#           sentence     word pos_tag chunk_tag ner_tag   lemmas  \
# document
# doc_0        sen_0   soccer      NN      B-NP       O   soccer
# doc_0        sen_0        -       :         O       O        -
# doc_0        sen_0    japan     NNP      B-NP   B-LOC    japan
# doc_0        sen_0      get      VB      B-VP       O      get
# doc_0        sen_0    lucky     NNP      B-NP       O    lucky
# ...            ...      ...     ...       ...     ...      ...
# doc_230   sen_3682  younger     JJR      I-NP       O  younger
# doc_230   sen_3682  brother      NN      I-NP       O  brother
# doc_230   sen_3682        ,       ,         O       O        ,
# doc_230   sen_3682    bobby     NNP      B-NP   B-PER    bobby
# doc_230   sen_3682        .       .         O     NaN        .
#
#                                                   hypernyms  \
# document
# doc_0                         ['football', 'football_game']
# doc_0                                                    []
# ...

# %%
df_test.columns
# Out:
# Index(['sentence', 'word', 'pos_tag', 'chunk_tag', 'ner_tag', 'lemmas',
#        'hypernyms', 'hyponyms', 'holonyms', 'meronyms'],
#       dtype='object')

# %%
# check 
type(df_test['hypernyms'][1])
# Out:
# str

# %% [markdown]
# ## clean test file
#
# 'hypernyms', 'hyponyms', 'holonyms', 'meronyms'

# %%
df_1 = df_test.copy()

df_1 = df_1.drop(['hypernyms', 'hyponyms', 'holonyms', 'meronyms'], axis=1 )

df_1
# Out:
#           sentence     word pos_tag chunk_tag ner_tag   lemmas
# document
# doc_0        sen_0   soccer      NN      B-NP       O   soccer
# doc_0        sen_0        -       :         O       O        -
# doc_0        sen_0    japan     NNP      B-NP   B-LOC    japan
# doc_0        sen_0      get      VB      B-VP       O      get
# doc_0        sen_0    lucky     NNP      B-NP       O    lucky
# ...            ...      ...     ...       ...     ...      ...
# doc_230   sen_3682  younger     JJR      I-NP       O  younger
# doc_230   sen_3682  brother      NN      I-NP       O  brother
# doc_230   sen_3682        ,       ,         O       O        ,
# doc_230   sen_3682    bobby     NNP      B-NP   B-PER    bobby
# doc_230   sen_3682        .       .         O     NaN        .
#
# [46435 rows x 6 columns]

# %%
hypernyms_list =[]

for i, string in enumerate(df_test['hypernyms'].tolist()):
    #print(row)
    string = string[1:]
    #print(i, string)
    row_list = string.split()
    #print(row_list)
    
    empty=''
    
    for word in row_list:
        word=word[1:-2]+' '
        empty = empty + word 
        #print(string)
    
    #print(empty)
    #print(type(string), string)
    hypernyms_list.append(empty.strip())


hypernyms_list  # 46434
# Out:
# ['football football_game',
#  '',
#  'lacquer lacquerware',
#  'gravel sicken confound stir go_forth channelise reproduce make discombobulate score attract nark go_away destroy catch create touch channelize confuse draw_in hurt draw rag bother throw prehend suffer nettle vex set_up seize ache return change_state irritate fuddle transmit annoy get_even rile effect receive get_at leave chafe understand ruin change acquire get_back pull_in hit get_to bedevil devil purchase turn tally transport clutch communicate modify experience buy intend mean intercommunicate fox effectuate come_down pull rack_up transfer undergo befuddle get alter have hear channel',
#  '',
#  'financial_gain triumph get victory acquire',
#  '',
#  'porcelain dishware crockery',
#  'linear_unit metal linear_measure metallic_element',
#  'modification attack act disruption assail impress astonishment amazement perturbation strike alteration affect change move',
# ...

# %%
df_1['hypernyms'] = hypernyms_list

df_1
# Out:
#           sentence     word pos_tag chunk_tag ner_tag   lemmas  \
# document
# doc_0        sen_0   soccer      NN      B-NP       O   soccer
# doc_0        sen_0        -       :         O       O        -
# doc_0        sen_0    japan     NNP      B-NP   B-LOC    japan
# doc_0        sen_0      get      VB      B-VP       O      get
# doc_0        sen_0    lucky     NNP      B-NP       O    lucky
# ...            ...      ...     ...       ...     ...      ...
# doc_230   sen_3682  younger     JJR      I-NP       O  younger
# doc_230   sen_3682  brother      NN      I-NP       O  brother
# doc_230   sen_3682        ,       ,         O       O        ,
# doc_230   sen_3682    bobby     NNP      B-NP   B-PER    bobby
# doc_230   sen_3682        .       .         O     NaN        .
#
#                                                   hypernyms
# document
# doc_0                                football football_game
# doc_0
# ...

# %%
# 'hypernyms', 'hyponyms', 'holonyms', 'meronyms'

hyponyms_list =[]

for i, string in enumerate(df_test['hyponyms'].tolist()):
    #print(row)
    string = string[1:]
    #print(i, string)
    row_list = string.split()
    #print(row_list)
    
    empty=''
    
    for word in row_list:
        word=word[1:-2]+' '
        empty = empty + word 
        #print(string)
    
    #print(empty)
    #print(type(string), string)
    hyponyms_list.append(empty.strip())

print(len(hyponyms_list))
hyponyms_list  # 46434
# Out:
# 46435
# ['',
#  '',
#  '',
# ...

# %%
# hyponyms

df_1['hyponyms']= hyponyms_list

df_1
# Out:
#           sentence     word pos_tag chunk_tag ner_tag   lemmas  \
# document
# doc_0        sen_0   soccer      NN      B-NP       O   soccer
# doc_0        sen_0        -       :         O       O        -
# doc_0        sen_0    japan     NNP      B-NP   B-LOC    japan
# doc_0        sen_0      get      VB      B-VP       O      get
# doc_0        sen_0    lucky     NNP      B-NP       O    lucky
# ...            ...      ...     ...       ...     ...      ...
# doc_230   sen_3682  younger     JJR      I-NP       O  younger
# doc_230   sen_3682  brother      NN      I-NP       O  brother
# doc_230   sen_3682        ,       ,         O       O        ,
# doc_230   sen_3682    bobby     NNP      B-NP   B-PER    bobby
# doc_230   sen_3682        .       .         O     NaN        .
#
#                                                   hypernyms  \
# document
# doc_0                                football football_game
# doc_0
# ...

# %%
# # 'hypernyms', 'hyponyms', 'holonyms', 'meronyms'

holonyms_list =[]

for i, string in enumerate(df_test['holonyms'].tolist()):
    #print(row)
    string = string[1:]
    #print(i, string)
    row_list = string.split()
    #print(row_list)
    
    empty=''
    
    for word in row_list:
        word=word[1:-2]+' '
        empty = empty + word 
        #print(string)
    
    #print(empty)
    #print(type(string), string)
    holonyms_list.append(empty.strip())

print(len(holonyms_list))
holonyms_list  # 46434
# Out:
# 46435
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Arabia Arabian_Peninsula',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Roman_alphabet Latin_alphabet',
#  '',
#  '',
#  '',
#  '',
#  'Arab_League',
#  '',
#  'Roman_alphabet Latin_alphabet',
#  '',
#  'Roman_alphabet Latin_alphabet',
#  '',
#  'peer_group',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'baseball_team',
#  'peer_group',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Roman_alphabet Latin_alphabet',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'CIS Commonwealth_of_Independent_States',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'peer_group',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'CIS Commonwealth_of_Independent_States',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Roman_alphabet Latin_alphabet',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
df_1['holonyms']= holonyms_list

df_1
# Out:
#           sentence     word pos_tag chunk_tag ner_tag   lemmas  \
# document
# doc_0        sen_0   soccer      NN      B-NP       O   soccer
# doc_0        sen_0        -       :         O       O        -
# doc_0        sen_0    japan     NNP      B-NP   B-LOC    japan
# doc_0        sen_0      get      VB      B-VP       O      get
# doc_0        sen_0    lucky     NNP      B-NP       O    lucky
# ...            ...      ...     ...       ...     ...      ...
# doc_230   sen_3682  younger     JJR      I-NP       O  younger
# doc_230   sen_3682  brother      NN      I-NP       O  brother
# doc_230   sen_3682        ,       ,         O       O        ,
# doc_230   sen_3682    bobby     NNP      B-NP   B-PER    bobby
# doc_230   sen_3682        .       .         O     NaN        .
#
#                                                   hypernyms  \
# document
# doc_0                                football football_game
# doc_0
# ...

# %%
# 'hypernyms', 'hyponyms', 'holonyms', 'meronyms'

meronyms_list =[]

for i, string in enumerate(df_test['meronyms'].tolist()):
    #print(row)
    string = string[1:]
    #print(i, string)
    row_list = string.split()
    #print(row_list)
    
    empty=''
    
    for word in row_list:
        word=word[1:-2]+' '
        empty = empty + word 
        #print(string)
    
    #print(empty)
    #print(type(string), string)
    meronyms_list.append(empty.strip())

print(len(meronyms_list))
meronyms_list  # 46434
# Out:
# 46435
# ['headshot',
#  '',
#  'Japanese_capital Yezo Yedo Toyota Mount_Asama Hokkaido Tokyo Hondo Toyohashi Fujiyama Honshu Asahikawa Kyoto Iwo_Jima Edo Omiya Naha_City Osaka_Bay Shikoku Fujinoyama Nagasaki Kammon_Strait_Bridge Fuji-san Tokio Yeddo Kyushu Kitakyushu Fuji Ezo Fukuoka Yokohama Ryukyu_Islands Nagano Mount_Fuji Osaka Volcano_Islands capital_of_Japan Asama Sapporo Toyonaki Nagoya',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
df_1['meronyms']= meronyms_list

df_1
# Out:
#           sentence     word pos_tag chunk_tag ner_tag   lemmas  \
# document
# doc_0        sen_0   soccer      NN      B-NP       O   soccer
# doc_0        sen_0        -       :         O       O        -
# doc_0        sen_0    japan     NNP      B-NP   B-LOC    japan
# doc_0        sen_0      get      VB      B-VP       O      get
# doc_0        sen_0    lucky     NNP      B-NP       O    lucky
# ...            ...      ...     ...       ...     ...      ...
# doc_230   sen_3682  younger     JJR      I-NP       O  younger
# doc_230   sen_3682  brother      NN      I-NP       O  brother
# doc_230   sen_3682        ,       ,         O       O        ,
# doc_230   sen_3682    bobby     NNP      B-NP   B-PER    bobby
# doc_230   sen_3682        .       .         O     NaN        .
#
#                                                   hypernyms  \
# document
# doc_0                                football football_game
# doc_0
# ...

# %%
df_1.columns
# Out:
# Index(['sentence', 'word', 'pos_tag', 'chunk_tag', 'ner_tag', 'lemmas',
#        'hypernyms', 'hyponyms', 'holonyms', 'meronyms'],
#       dtype='object')

# %%
df_1 = df_1[['sentence','word','pos_tag', 'chunk_tag', 'lemmas',
       'hypernyms', 'hyponyms', 'holonyms', 'meronyms', 'ner_tag']]

df_1.reset_index(inplace=True)

df_1 = df_1.drop('index', axis=1)

df_1
# Out:
#        sentence     word pos_tag chunk_tag   lemmas  \
# 0         sen_0   soccer      NN      B-NP   soccer
# 1         sen_0        -       :         O        -
# 2         sen_0    japan     NNP      B-NP    japan
# 3         sen_0      get      VB      B-VP      get
# 4         sen_0    lucky     NNP      B-NP    lucky
# ...         ...      ...     ...       ...      ...
# 46430  sen_3682  younger     JJR      I-NP  younger
# 46431  sen_3682  brother      NN      I-NP  brother
# 46432  sen_3682        ,       ,         O        ,
# 46433  sen_3682    bobby     NNP      B-NP    bobby
# 46434  sen_3682        .       .         O        .
#
#                                                hypernyms  \
# 0                                 football football_game
# 1
# 2                                    lacquer lacquerware
# 3      gravel sicken confound stir go_forth channelis...
# 4
# ...                                                  ...
# 46430
# ...

# %%
df_1.columns
# Out:
# Index(['sentence', 'word', 'pos_tag', 'chunk_tag', 'lemmas', 'hypernyms',
#        'hyponyms', 'holonyms', 'meronyms', 'ner_tag'],
#       dtype='object')

# %%
label =[]
for i in df_1['ner_tag'].tolist():
    try:
        if i=='O':
            label.append(0)
        elif i=='B-LOC':
            label.append(2)
        elif i=='I-LOC':
            label.append(2)
        elif i=='B-PER':
            label.append(1)
        elif i=='I-PER':
            label.append(1)
        elif i=='B-MISC':
            label.append(4)
        elif i=='I-MISC':
            label.append(4)
        elif i== 'B-ORG':
            label.append(3)
        elif i== 'I-ORG':
            label.append(3)
    except Exception as e:
        print(i+" "+str(e))
            
label.append(0)

# %%
df_1['target']=label

df_1
# Out:
#        sentence     word pos_tag chunk_tag   lemmas  \
# 0         sen_0   soccer      NN      B-NP   soccer
# 1         sen_0        -       :         O        -
# 2         sen_0    japan     NNP      B-NP    japan
# 3         sen_0      get      VB      B-VP      get
# 4         sen_0    lucky     NNP      B-NP    lucky
# ...         ...      ...     ...       ...      ...
# 46430  sen_3682  younger     JJR      I-NP  younger
# 46431  sen_3682  brother      NN      I-NP  brother
# 46432  sen_3682        ,       ,         O        ,
# 46433  sen_3682    bobby     NNP      B-NP    bobby
# 46434  sen_3682        .       .         O        .
#
#                                                hypernyms  \
# 0                                 football football_game
# 1
# 2                                    lacquer lacquerware
# 3      gravel sicken confound stir go_forth channelis...
# 4
# ...                                                  ...
# 46430
# ...

# %%
df_1.columns
# Out:
# Index(['sentence', 'word', 'pos_tag', 'chunk_tag', 'lemmas', 'hypernyms',
#        'hyponyms', 'holonyms', 'meronyms', 'ner_tag', 'target'],
#       dtype='object')

# %%
df_1 = df_1[['sentence', 'word','pos_tag', 'chunk_tag', 'lemmas', 'hypernyms', 'hyponyms', 'holonyms',
       'meronyms', 'target']]

df_1
# Out:
#        sentence     word pos_tag chunk_tag   lemmas  \
# 0         sen_0   soccer      NN      B-NP   soccer
# 1         sen_0        -       :         O        -
# 2         sen_0    japan     NNP      B-NP    japan
# 3         sen_0      get      VB      B-VP      get
# 4         sen_0    lucky     NNP      B-NP    lucky
# ...         ...      ...     ...       ...      ...
# 46430  sen_3682  younger     JJR      I-NP  younger
# 46431  sen_3682  brother      NN      I-NP  brother
# 46432  sen_3682        ,       ,         O        ,
# 46433  sen_3682    bobby     NNP      B-NP    bobby
# 46434  sen_3682        .       .         O        .
#
#                                                hypernyms  \
# 0                                 football football_game
# 1
# 2                                    lacquer lacquerware
# 3      gravel sicken confound stir go_forth channelis...
# 4
# ...                                                  ...
# 46430
# ...

# %%
df_1.to_csv("test_extracted_features_step_3.csv", index=False)

# %% [markdown]
# ## clean Train file

# %%
df_2 = df_train.copy()

df_2 = df_2.drop(['hypernyms', 'hyponyms', 'holonyms', 'meronyms'], axis=1 )

df_2
# Out:
#            sentence          word pos_tag chunk_tag ner_tag        lemmas
# document
# doc_0         sen_0            eu     NNP      B-NP   B-ORG            eu
# doc_0         sen_0       rejects     VBZ      B-VP       O        reject
# doc_0         sen_0        german      JJ      B-NP  B-MISC        german
# doc_0         sen_0          call      NN      I-NP       O          call
# doc_0         sen_0            to      TO      B-VP       O            to
# ...             ...           ...     ...       ...     ...           ...
# doc_1161  sen_18450             .       .         O       O             .
# doc_1161  sen_18451            --       :         O       O            --
# doc_1161  sen_18451         dhaka     NNP      B-NP   B-ORG         dhaka
# doc_1161  sen_18451      newsroom     NNP      I-NP   I-ORG      newsroom
# doc_1161  sen_18451  880-2-506363      CD      I-NP     NaN  880-2-506363
#
# [254983 rows x 6 columns]

# %%
hypernyms_list =[]

for i, string in enumerate(df_train['hypernyms'].tolist()):
    #print(row)
    string = string[1:]
    #print(i, string)
    row_list = string.split()
    #print(row_list)
    
    empty=''
    
    for word in row_list:
        word=word[1:-2]+' '
        empty = empty + word 
        #print(string)
    
    #print(empty)
    #print(type(string), string)
    hypernyms_list.append(empty.strip())


hypernyms_list  # 46434
# Out:
# ['metal world_organisation world_organization international_organization international_organisation global_organization metallic_element',
#  'refuse evaluate react decline judge deciding decision_making respond pass_judgment',
#  'West_Germanic_language European West_Germanic',
#  'shelve read disposition wake inclination require play let_loose declare telephone quest awaken stop_over tempt see demand enjoin remit arouse command call_for request emit statement guess gainsay animal_communication program_line vocalization lure asking get_together order consider ask telephony prorogue postpone reckon address dispute regard stop put_over adjudge tendency waken telecommunicate utterance utter set_back put_off exact pretend table meet expect rouse defer let_out label say visit indicate hazard venture conclusion challenge turn_to determination tell view instruction decision hold hold_over wake_up bespeak option entice',
#  '',
#  'ostracise protest objection ostracize dissent',
# ...

# %%
df_2['hypernyms'] = hypernyms_list

df_2
# Out:
#            sentence          word pos_tag chunk_tag ner_tag        lemmas  \
# document
# doc_0         sen_0            eu     NNP      B-NP   B-ORG            eu
# doc_0         sen_0       rejects     VBZ      B-VP       O        reject
# doc_0         sen_0        german      JJ      B-NP  B-MISC        german
# doc_0         sen_0          call      NN      I-NP       O          call
# doc_0         sen_0            to      TO      B-VP       O            to
# ...             ...           ...     ...       ...     ...           ...
# doc_1161  sen_18450             .       .         O       O             .
# doc_1161  sen_18451            --       :         O       O            --
# doc_1161  sen_18451         dhaka     NNP      B-NP   B-ORG         dhaka
# doc_1161  sen_18451      newsroom     NNP      I-NP   I-ORG      newsroom
# doc_1161  sen_18451  880-2-506363      CD      I-NP     NaN  880-2-506363
#
#                                                   hypernyms
# ...

# %%
# 'hypernyms', 'hyponyms', 'holonyms', 'meronyms'

hyponyms_list =[]

for i, string in enumerate(df_train['hyponyms'].tolist()):
    #print(row)
    string = string[1:]
    #print(i, string)
    row_list = string.split()
    #print(row_list)
    
    empty=''
    
    for word in row_list:
        word=word[1:-2]+' '
        empty = empty + word 
        #print(string)
    
    #print(empty)
    #print(type(string), string)
    hyponyms_list.append(empty.strip())

print(len(hyponyms_list))
hyponyms_list  # 46434
# Out:
# 254983
# ['',
#  'brush_aside recuse disregard snub object discourage reprobate disown discredit deprecate repudiate renounce repel push_aside dishonor brush_off dismiss rebuff dishonour discount bounce deter ignore disbelieve',
#  'Middle_High_German Prussian Hun Jerry Teuton Kraut Bavarian Krauthead East_German Boche Old_High_German Pennsylvania_Dutch Yiddish Berliner',
# ...

# %%
# hyponyms

df_2['hyponyms']= hyponyms_list

df_2
# Out:
#            sentence          word pos_tag chunk_tag ner_tag        lemmas  \
# document
# doc_0         sen_0            eu     NNP      B-NP   B-ORG            eu
# doc_0         sen_0       rejects     VBZ      B-VP       O        reject
# doc_0         sen_0        german      JJ      B-NP  B-MISC        german
# doc_0         sen_0          call      NN      I-NP       O          call
# doc_0         sen_0            to      TO      B-VP       O            to
# ...             ...           ...     ...       ...     ...           ...
# doc_1161  sen_18450             .       .         O       O             .
# doc_1161  sen_18451            --       :         O       O            --
# doc_1161  sen_18451         dhaka     NNP      B-NP   B-ORG         dhaka
# doc_1161  sen_18451      newsroom     NNP      I-NP   I-ORG      newsroom
# doc_1161  sen_18451  880-2-506363      CD      I-NP     NaN  880-2-506363
#
#                                                   hypernyms  \
# ...

# %%
# # 'hypernyms', 'hyponyms', 'holonyms', 'meronyms'

holonyms_list =[]

for i, string in enumerate(df_train['holonyms'].tolist()):
    #print(row)
    string = string[1:]
    #print(i, string)
    row_list = string.split()
    #print(row_list)
    
    empty=''
    
    for word in row_list:
        word=word[1:-2]+' '
        empty = empty + word 
        #print(string)
    
    #print(empty)
    #print(type(string), string)
    holonyms_list.append(empty.strip())

print(len(holonyms_list))
holonyms_list  # 46434
# Out:
# 254983
# ['',
#  '',
#  'Deutschland Germany FRG Federal_Republic_of_Germany',
#  '',
#  '',
#  '',
#  '',
#  'Ovis genus_Ovis',
#  '',
#  '',
#  'Dendroica genus_Dendroica',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Deutschland Germany FRG Federal_Republic_of_Germany',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Ovis genus_Ovis',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'flock fold Ovis herd genus_Ovis',
#  '',
#  'European_Community European_Union EEC North_Atlantic_Treaty_Organization European_Economic_Community Europe EU NATO Common_Market EC',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'European_Community European_Union EEC North_Atlantic_Treaty_Organization European_Economic_Community Europe EU NATO Common_Market EC',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
df_2['holonyms']= holonyms_list

df_2
# Out:
#            sentence          word pos_tag chunk_tag ner_tag        lemmas  \
# document
# doc_0         sen_0            eu     NNP      B-NP   B-ORG            eu
# doc_0         sen_0       rejects     VBZ      B-VP       O        reject
# doc_0         sen_0        german      JJ      B-NP  B-MISC        german
# doc_0         sen_0          call      NN      I-NP       O          call
# doc_0         sen_0            to      TO      B-VP       O            to
# ...             ...           ...     ...       ...     ...           ...
# doc_1161  sen_18450             .       .         O       O             .
# doc_1161  sen_18451            --       :         O       O            --
# doc_1161  sen_18451         dhaka     NNP      B-NP   B-ORG         dhaka
# doc_1161  sen_18451      newsroom     NNP      I-NP   I-ORG      newsroom
# doc_1161  sen_18451  880-2-506363      CD      I-NP     NaN  880-2-506363
#
#                                                   hypernyms  \
# ...

# %%
# 'hypernyms', 'hyponyms', 'holonyms', 'meronyms'

meronyms_list =[]

for i, string in enumerate(df_train['meronyms'].tolist()):
    #print(row)
    string = string[1:]
    #print(i, string)
    row_list = string.split()
    #print(row_list)
    
    empty=''
    
    for word in row_list:
        word=word[1:-2]+' '
        empty = empty + word 
        #print(string)
    
    #print(empty)
    #print(type(string), string)
    meronyms_list.append(empty.strip())

print(len(meronyms_list))
meronyms_list  # 46434
# Out:
# 254983
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'cut_of_lamb loin_of_lamb',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'cut_of_lamb loin_of_lamb',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'bag udder poll',
#  'symptom syndrome sign',
#  'can stool crapper potty toilet_seat throne toilet_bowl toilet pot commode',
#  '',
#  '',
#  '',
#  'trotter withers',
#  '',
# ...

# %%
df_2['meronyms']= meronyms_list

df_2
# Out:
#            sentence          word pos_tag chunk_tag ner_tag        lemmas  \
# document
# doc_0         sen_0            eu     NNP      B-NP   B-ORG            eu
# doc_0         sen_0       rejects     VBZ      B-VP       O        reject
# doc_0         sen_0        german      JJ      B-NP  B-MISC        german
# doc_0         sen_0          call      NN      I-NP       O          call
# doc_0         sen_0            to      TO      B-VP       O            to
# ...             ...           ...     ...       ...     ...           ...
# doc_1161  sen_18450             .       .         O       O             .
# doc_1161  sen_18451            --       :         O       O            --
# doc_1161  sen_18451         dhaka     NNP      B-NP   B-ORG         dhaka
# doc_1161  sen_18451      newsroom     NNP      I-NP   I-ORG      newsroom
# doc_1161  sen_18451  880-2-506363      CD      I-NP     NaN  880-2-506363
#
#                                                   hypernyms  \
# ...

# %%
df_2 = df_2[['sentence','word','pos_tag', 'chunk_tag', 'lemmas',
       'hypernyms', 'hyponyms', 'holonyms', 'meronyms', 'ner_tag']]

df_2.reset_index(inplace=True)

df_2 = df_2.drop('index', axis=1)

df_2
# Out:
#          sentence          word pos_tag chunk_tag        lemmas  \
# 0           sen_0            eu     NNP      B-NP            eu
# 1           sen_0       rejects     VBZ      B-VP        reject
# 2           sen_0        german      JJ      B-NP        german
# 3           sen_0          call      NN      I-NP          call
# 4           sen_0            to      TO      B-VP            to
# ...           ...           ...     ...       ...           ...
# 254978  sen_18450             .       .         O             .
# 254979  sen_18451            --       :         O            --
# 254980  sen_18451         dhaka     NNP      B-NP         dhaka
# 254981  sen_18451      newsroom     NNP      I-NP      newsroom
# 254982  sen_18451  880-2-506363      CD      I-NP  880-2-506363
#
#                                                 hypernyms  \
# 0       metal world_organisation world_organization in...
# 1       refuse evaluate react decline judge deciding d...
# ...

# %%
label =[]
for i in df_2['ner_tag'].tolist():
    try:
        if i=='O':
            label.append(0)
        elif i=='B-LOC':
            label.append(2)
        elif i=='I-LOC':
            label.append(2)
        elif i=='B-PER':
            label.append(1)
        elif i=='I-PER':
            label.append(1)
        elif i=='B-MISC':
            label.append(4)
        elif i=='I-MISC':
            label.append(4)
        elif i== 'B-ORG':
            label.append(3)
        elif i== 'I-ORG':
            label.append(3)
    except Exception as e:
        print(i+" "+str(e))
            
label.append(0)

# %%
df_2['target']=label

df_2
# Out:
#          sentence          word pos_tag chunk_tag        lemmas  \
# 0           sen_0            eu     NNP      B-NP            eu
# 1           sen_0       rejects     VBZ      B-VP        reject
# 2           sen_0        german      JJ      B-NP        german
# 3           sen_0          call      NN      I-NP          call
# 4           sen_0            to      TO      B-VP            to
# ...           ...           ...     ...       ...           ...
# 254978  sen_18450             .       .         O             .
# 254979  sen_18451            --       :         O            --
# 254980  sen_18451         dhaka     NNP      B-NP         dhaka
# 254981  sen_18451      newsroom     NNP      I-NP      newsroom
# 254982  sen_18451  880-2-506363      CD      I-NP  880-2-506363
#
#                                                 hypernyms  \
# 0       metal world_organisation world_organization in...
# 1       refuse evaluate react decline judge deciding d...
# ...

# %%
df_2 = df_2[['sentence','word','pos_tag', 'chunk_tag', 'lemmas', 'hypernyms', 'hyponyms', 'holonyms',
       'meronyms', 'target']]

df_2
# Out:
#          sentence          word pos_tag chunk_tag        lemmas  \
# 0           sen_0            eu     NNP      B-NP            eu
# 1           sen_0       rejects     VBZ      B-VP        reject
# 2           sen_0        german      JJ      B-NP        german
# 3           sen_0          call      NN      I-NP          call
# 4           sen_0            to      TO      B-VP            to
# ...           ...           ...     ...       ...           ...
# 254978  sen_18450             .       .         O             .
# 254979  sen_18451            --       :         O            --
# 254980  sen_18451         dhaka     NNP      B-NP         dhaka
# 254981  sen_18451      newsroom     NNP      I-NP      newsroom
# 254982  sen_18451  880-2-506363      CD      I-NP  880-2-506363
#
#                                                 hypernyms  \
# 0       metal world_organisation world_organization in...
# 1       refuse evaluate react decline judge deciding d...
# ...

# %%
df_2.columns
# Out:
# Index(['sentence', 'word', 'pos_tag', 'chunk_tag', 'lemmas', 'hypernyms',
#        'hyponyms', 'holonyms', 'meronyms', 'target'],
#       dtype='object')

# %%
df_2.to_csv("train_extracted_features_step_3.csv", index=False)
